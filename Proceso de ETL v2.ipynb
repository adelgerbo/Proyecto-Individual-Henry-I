# %%
# Importamos las librerias necesarias
import pandas as pd
from pandasql import sqldf

# %%
# Importamos los archivos CSV, uno para cada servicio de streaming
Amazon = pd.read_csv("Datasets/amazon_prime_titles-score.csv")
Disney = pd.read_csv("Datasets/Disney_plus_titles-score.csv")
Hulu = pd.read_csv("Datasets/hulu_titles-score (2).csv")
Netflix = pd.read_csv("Datasets/netflix_titles-score.csv")

# %%
# Verificamos la importaciòn correcta de los datasets
Amazon.head()

# %%
Disney.head()

# %%
Hulu.tail()

# %%
Netflix.tail()

# %%
"""
Generamos el campo id: Cada id se compondrá de la primera letra del
nombre de la plataforma, seguido del show_id ya presente en los 
datasets (ejemplo para títulos de Amazon = as123)
"""
Amazon.insert(loc = 0,
          column = 'id',
          value = "a"+Amazon["show_id"])

Disney.insert(loc = 0,
          column = 'id',
          value = "d"+Disney["show_id"])

Hulu.insert(loc = 0,
          column = 'id',
          value = "h"+Hulu["show_id"])

Netflix.insert(loc = 0,
          column = 'id',
          value = "n"+Netflix["show_id"])

# %%
# Comprobamos la correcta inserciòn del nuevo campo
Netflix.head()

# %%
"""
Juntamos todos los datasets en uno solo, ya que contamos 
con el campo id para diferenciar el servicio, y las
transformaciones a continuación se aplican a todos por igual
"""

moviesdb = Amazon.append(Disney).append(Hulu).append(Netflix)

# %%
#Verificamos el resultado
moviesdb.head()

# %%
moviesdb.tail()

# %%
# Verificamos existencia y cantidad de nulos por columna en el dataframe
moviesdb.isnull().sum()

# %%
"""
Reemplazamos los valores nulos del campo "Rating" por la letra "G"
(corresponde al maturity rating "General por all audiences")
"""
moviesdb["rating"].fillna("G", inplace = True)

# %%
# Controlamos la correcciòn sobre la columna "rating"
moviesdb.isnull().sum()

# %%
# Visualizamos el dataframe modificado
moviesdb.head(30)

# %%
# Cambiamos el formato de la columna "date_added" a AAAA-mm-dd
moviesdb["date_added"] = pd.to_datetime(moviesdb["date_added"])

# %%
# Verificamos
moviesdb.tail()

# %%
# Pasamos a minúsculas los campos de texto
moviesdb["type"] = moviesdb["type"].str.lower()
moviesdb["title"] = moviesdb["title"].str.lower()
moviesdb["director"] = moviesdb["director"].str.lower()
moviesdb["cast"] = moviesdb["cast"].str.lower()
moviesdb["country"] = moviesdb["country"].str.lower()
moviesdb["rating"] = moviesdb["rating"].str.lower()
moviesdb["duration"] = moviesdb["duration"].str.lower()
moviesdb["listed_in"] = moviesdb["listed_in"].str.lower()
moviesdb["description"] = moviesdb["description"].str.lower()

# %%
# Verificamos
moviesdb.head()

# %%
# Separamos el campo "duration" en 2 columnas
splitcolumns = moviesdb["duration"].str.split(" ", n = 1, expand = True)
 
# Insertamos una columna con las cantidades
moviesdb["duration_int"] = splitcolumns[0]
 
# Insertamos una columna con la unidad de medición
moviesdb["duration_type"] = splitcolumns[1]

# %%
# Reemplazamos "seasons" por "season" en la columna "duration_type"
moviesdb['duration_type'] = moviesdb['duration_type'].str.replace('seasons','season')

# %%
# Cambiamor el formato del campo "duration_int" a integer
moviesdb['duration_int'] = moviesdb['duration_int'].astype("Int64")

# %%
#Verificamos
moviesdb.head(15)
# Out:
#       id show_id   type                              title  \
# 0    as1      s1  movie                the grand seduction
# 1    as2      s2  movie               take care good night
# 2    as3      s3  movie               secrets of deception
# 3    as4      s4  movie                 pink: staying true
# 4    as5      s5  movie                      monster maker
# 5    as6      s6  movie              living with dinosaurs
# 6    as7      s7  movie                          hired gun
# 7    as8      s8  movie                       grease live!
# 8    as9      s9  movie                    global meltdown
# 9   as10     s10  movie                     david's mother
# 10  as11     s11  movie                     forest fairies
# 11  as12     s12  movie                          take care
# 12  as13     s13  movie           the night eats the world
# 13  as14     s14  movie                         resilencia
# 14  as15     s15  movie  elon musk: the real life iron man
#
#                        director  \
# 0                  don mckellar
# 1                  girish joshi
# 2                   josh webber
# 3                sonia anderson
# 4                  giles foster
# 5                  paul weiland
# 6                   fran strine
# 7   thomas kail, alex rudzinski
# 8                 daniel gilboy
# 9         robert allan ackerman
# 10               justin g. dyck
# 11                 liz tuccillo
# 12             dominique rocher
# 13                jep barcelona
# 14               sonia anderson
#
#                                                  cast         country  \
# 0      brendan gleeson, taylor kitsch, gordon pinsent          canada
# 1    mahesh manjrekar, abhay mahajan, sachin khedekar           india
# 2   tom sizemore, lorenzo lamas, robert lasardo, r...   united states
# 3   interviews with: pink, adele, beyoncé, britney...   united states
# 4   harry dean stanton, kieran o'brien, george cos...  united kingdom
# 5   gregory chisholm, juliet stevenson, brian hens...  united kingdom
# 6   alice cooper, liberty devitto, ray parker jr.,...   united states
# 7   julianne hough, aaron tveit, vanessa hudgens, ...   united states
# 8   michael paré, leanne khol young, patrick j. ma...          canada
# 9     kirstie alley, sam waterston, stockard channing   united states
# 10  emily wilder, adrian cowan, gary mckenzie, jer...          canada
# 11            leslie bibb, kevin curtis, nadia dajani   united states
# 12  anders danielsen lie, golshifteh farahani, den...          france
# 13  rafinha alcantara, marc-andré ter stegen, serg...           spain
# 14  elon musk, per wimmer, julie anderson-ankenbra...  united kingdom
#
#    date_added  release_year rating duration  \
# 0  2021-03-30          2014      g  113 min
# 1  2021-03-30          2018    13+  110 min
# 2  2021-03-30          2017      g   74 min
# 3  2021-03-30          2014      g   69 min
# 4  2021-03-30          1989      g   45 min
# 5  2021-03-30          1989      g   52 min
# 6  2021-03-30          2017      g   98 min
# 7  2021-03-30          2016      g  131 min
# 8  2021-03-30          2017      g   87 min
# 9  2021-04-01          1994      g   92 min
# 10 2021-04-04          2016      g   88 min
# 11 2021-04-10          2014      g   93 min
# 12 2021-04-17          2018      g   94 min
# 13 2021-04-24          2020      g   46 min
# 14 2021-05-02          2018      g   74 min
#
#                             listed_in  \
# 0                       comedy, drama
# 1                drama, international
# 2             action, drama, suspense
# 3                         documentary
# 4                      drama, fantasy
# 5                       fantasy, kids
# 6       documentary, special interest
# 7                              comedy
# 8   action, science fiction, suspense
# 9                               drama
# 10                    adventure, kids
# 11                             comedy
# 12                   horror, suspense
# 13                documentary, sports
# 14                        documentary
#
#                                           description  score  duration_int  \
# 0   a small fishing village must procure a local d...     99           113
# 1   a metro family decides to fight a cyber crimin...     37           110
# 2   after a man discovers his wife is cheating on ...     20            74
# 3   pink breaks the mold once again, bringing her ...     27            69
# 4   teenage matt banting wants to work with a famo...     75            45
# 5   the story unfolds in a an english seaside town...     74            52
# 6   they are the "first call, a-list" musicians, j...     50            98
# 7   this honest, uncompromising comedy chronicles ...     84           131
# 8   a helicopter pilot and an environmental scient...     46            87
# 9   sally goodson is a devoted mother to her autis...     70            92
# 10  amanda stumbles upon a hidden village of fairi...     18            88
# 11  when a car crash leaves frannie immobilized, s...     44            93
# 12  after waking up in an apartment the night afte...     35            94
# 13  the documentary follows the midfielder’s every...      6            46
# 14  discover the meteoric rise of elon musk, the m...     87            74
#
#    duration_type
# 0            min
# 1            min
# 2            min
# 3            min
# 4            min
# 5            min
# 6            min
# 7            min
# 8            min
# 9            min
# 10           min
# 11           min
# 12           min
# 13           min
# 14           min

# %%
moviesdb.info()

# %%
"""
Comenzamos con las consultas al dataframe. Esta función nos evitará pasar variables
globales cada vez que usemos un objeto
"""
pysqldf = lambda q: sqldf(q, globals())

# %%
""""
Definimos la función para el siguiente requerimiento: Cantidad de veces que aparece 
una keyword en el título de peliculas/series, por plataforma
"""
def veces_keyword(keyword,plataforma):
        if plataforma == "amazon":
                plat = "a%"
        elif plataforma == "netflix":
                plat = "n%"
        elif plataforma == "hulu":
                plat = "h%"
        elif plataforma == "disney":
                plat = "d%"

        query = """SELECT SUM (LENGTH(title) - LENGTH(REPLACE(title,'"""+keyword+"""',""))) / LENGTH('"""+keyword+"""')
        as cantidad
        FROM moviesdb
        WHERE id LIKE '"""+plat+"""' """ 
        veces = pysqldf(query)
        return veces.to_string(index=False, header=False)

# %%
query = """SELECT SUM (LENGTH(title) - LENGTH(REPLACE(title,"zombie",""))) / LENGTH("zombie")
        as cantidad
        FROM moviesdb
        WHERE id LIKE "a%" """
veces = pysqldf(query)
veces
# Out:
#    cantidad
# 0        15

# %%
query = """SELECT COUNT(title)
        FROM moviesdb
        WHERE score > 99
        AND id LIKE "h%" """
veces = pysqldf(query)
veces
# Out:
#    COUNT(title)
# 0            27

# %%
query = """SELECT title
        FROM moviesdb
        WHERE id LIKE "h%"
        ORDER BY score DESC, title ASC
        LIMIT 1,1"""
veces = pysqldf(query)
veces
# Out:
#                                    title
# 0  along with the gods: the last 49 days

# %%
query = """SELECT title
        FROM moviesdb
        WHERE id LIKE "h%"
        AND release_year = 2014
        AND duration_type = "min"
        AND duration_int = (SELECT MAX(duration_int)
        FROM moviesdb
        WHERE id LIKE "h%"
        AND release_year = 2014
        AND duration_type = "min")
        """
veces = pysqldf(query)
veces
# Out:
#        title
# 0  gone girl

# %%
query = """SELECT count(title)
        FROM moviesdb
        WHERE rating = "g" """
veces = pysqldf(query)
veces
# Out:
#    count(title)
# 0          1269
